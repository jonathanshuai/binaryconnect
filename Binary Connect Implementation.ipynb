# %% [markdown]
# # Binary Connect Implementation

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F

from torchvision import datasets, transforms
import numpy as np

batch_size = 128
n_epochs = 1000
validation_steps = 10
learning_rate = 1e-3


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
train_loader = torch.utils.data.DataLoader(
        datasets.MNIST('./data', train=True, download=True,
                        transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.5,), (0.5,))
                       ])), batch_size=batch_size, shuffle=True)

valid_loader = torch.utils.data.DataLoader(
        datasets.MNIST('./data', train=False, 
                        transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.5,), (0.5,))
                       ])), batch_size=batch_size, shuffle=True)

# %%
class DNNModel(nn.Module):
    def __init__(self, image_size, output_size=10, hidden_size=1024):
        super(DNNModel, self).__init__()
        
        self.image_size = image_size
        
        self.fc1 = nn.Sequential(
                   nn.Linear(image_size * image_size, hidden_size),
                   nn.LeakyReLU(0.2),
                   nn.BatchNorm1d(hidden_size))
        self.fc2 = nn.Sequential(
                   nn.Linear(hidden_size, hidden_size),
                   nn.LeakyReLU(0.2),
                   nn.BatchNorm1d(hidden_size))
        self.fc3 = nn.Sequential(
                   nn.Linear(hidden_size, hidden_size),
                   nn.LeakyReLU(0.2),
                   nn.BatchNorm1d(hidden_size))
        self.output_layer = nn.Sequential(
                    nn.Linear(hidden_size, output_size),
                    nn.LeakyReLU(0.2),
                    nn.BatchNorm1d(output_size))
        
    def forward(self, x):
        x = x.view(-1, self.image_size * self.image_size)
        
        for layer in [self.fc1, self.fc2, self.fc3, self.output_layer]:
            x = layer(x)
        return x
    
class L2SVMLoss(nn.Module):
    def __init__(self):
        super(L2SVMLoss, self).__init__()
    
    def forward(self, output, target):
        y = one_hot_encoding(target)
        ot = output * y
        loss = torch.sum(torch.sqrt(F.relu(1 - ot)))
        return loss
    
def one_hot_encoding(labels):
    y = torch.eye(10) * 2 - 1
    return y[labels].to(device)

# %%
model = DNNModel(image_size=28).to(device)
loss_function = L2SVMLoss().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
print("Training...")

for epoch in range(n_epochs):
    print("========[EPOCH {}/{}]========".format(epoch, n_epochs))
    
    # Training
    train_acc = 0
    train_loss = 0
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = loss_function(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.data.cpu().numpy()
        train_acc += np.mean(torch.argmax(outputs, 1).data.cpu().numpy() == labels.data.cpu().numpy())

    train_acc = train_acc / len(train_loader)
    print("[TRAIN ACCURACY]: {:.4f}".format(train_acc))
    print("[TRAIN LOSS]: {:.4f}".format(train_loss))

    if epoch % validation_steps == 0:
        # Validation
        valid_acc = 0
        for i, (images, labels) in enumerate(valid_loader):
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            valid_acc += np.mean(torch.argmax(outputs, 1).data.cpu().numpy() == labels.data.cpu().numpy())

        valid_acc = valid_acc / len(valid_loader)
        print("[VALIDATION ACCURACY]: {:.4f}".format(valid_acc))
# Out:
# Training...
# ========[EPOCH 0/1000]========
# [TRAIN ACCURACY]: 0.8579
# [TRAIN LOSS]: 43958.0797
# [VALIDATION ACCURACY]: 0.7947
# ========[EPOCH 1/1000]========
# [TRAIN ACCURACY]: 0.9021
# [TRAIN LOSS]: 29371.6306
# ========[EPOCH 2/1000]========
# [TRAIN ACCURACY]: 0.9386
# [TRAIN LOSS]: 19208.1137
# ========[EPOCH 3/1000]========
# [TRAIN ACCURACY]: 0.9542
# [TRAIN LOSS]: 13316.7394
# ========[EPOCH 4/1000]========
# [TRAIN ACCURACY]: 0.9593
# [TRAIN LOSS]: 11785.0189
# ========[EPOCH 5/1000]========
# [TRAIN ACCURACY]: 0.9530
# [TRAIN LOSS]: 13659.6593
# ========[EPOCH 6/1000]========
# [TRAIN ACCURACY]: 0.9264
# [TRAIN LOSS]: 18770.6326
# ========[EPOCH 7/1000]========
# [TRAIN ACCURACY]: 0.9504
# [TRAIN LOSS]: 14458.1929
# ========[EPOCH 8/1000]========
# [TRAIN ACCURACY]: 0.9449
# [TRAIN LOSS]: 15280.7611
# ========[EPOCH 9/1000]========
# [TRAIN ACCURACY]: 0.9650
# [TRAIN LOSS]: 10765.3166
# ========[EPOCH 10/1000]========
# [TRAIN ACCURACY]: 0.9678
# [TRAIN LOSS]: 9531.6880
# [VALIDATION ACCURACY]: 0.9622
# ========[EPOCH 11/1000]========
# [TRAIN ACCURACY]: 0.9660
# [TRAIN LOSS]: 10077.5595
# ========[EPOCH 12/1000]========
# [TRAIN ACCURACY]: 0.9649
# [TRAIN LOSS]: 10282.2280
# ========[EPOCH 13/1000]========
# [TRAIN ACCURACY]: 0.9702
# [TRAIN LOSS]: 8755.1339
# ========[EPOCH 14/1000]========
# [TRAIN ACCURACY]: 0.9732
# [TRAIN LOSS]: 8043.5502
# ========[EPOCH 15/1000]========
# [TRAIN ACCURACY]: 0.9746
# [TRAIN LOSS]: 7539.7309
# ========[EPOCH 16/1000]========
# [TRAIN ACCURACY]: 0.9775
# [TRAIN LOSS]: 6623.7778
# ========[EPOCH 17/1000]========
# [TRAIN ACCURACY]: 0.9687
# [TRAIN LOSS]: 9046.8788
# ========[EPOCH 18/1000]========
# [TRAIN ACCURACY]: 0.9762
# [TRAIN LOSS]: 6871.4940
# ========[EPOCH 19/1000]========
# [TRAIN ACCURACY]: 0.9777
# [TRAIN LOSS]: 6570.9609
# ========[EPOCH 20/1000]========
# [TRAIN ACCURACY]: 0.9794
# [TRAIN LOSS]: 6050.9170
# [VALIDATION ACCURACY]: 0.9731
# ========[EPOCH 21/1000]========
# [TRAIN ACCURACY]: 0.9791
# [TRAIN LOSS]: 6344.0889
# ========[EPOCH 22/1000]========
# [TRAIN ACCURACY]: 0.9826
# [TRAIN LOSS]: 5249.0819
# ========[EPOCH 23/1000]========
# [TRAIN ACCURACY]: 0.9833
# [TRAIN LOSS]: 5024.1206
# ========[EPOCH 24/1000]========
# [TRAIN ACCURACY]: 0.9829
# [TRAIN LOSS]: 5257.6577
# ========[EPOCH 25/1000]========
# [TRAIN ACCURACY]: 0.9840
# [TRAIN LOSS]: 4721.4304
# ========[EPOCH 26/1000]========
# [TRAIN ACCURACY]: 0.9859
# [TRAIN LOSS]: 4245.8077
# ========[EPOCH 27/1000]========
# [TRAIN ACCURACY]: 0.9847
# [TRAIN LOSS]: 4776.8570
# ========[EPOCH 28/1000]========
# [TRAIN ACCURACY]: 0.9816
# [TRAIN LOSS]: 5356.9145
# ========[EPOCH 29/1000]========
# [TRAIN ACCURACY]: 0.9510
# [TRAIN LOSS]: 12886.6703
# ========[EPOCH 30/1000]========
# [TRAIN ACCURACY]: 0.9462
# [TRAIN LOSS]: 15177.7988
# [VALIDATION ACCURACY]: 0.9630
# ========[EPOCH 31/1000]========
# [TRAIN ACCURACY]: 0.9674
# [TRAIN LOSS]: 10212.1280
# ========[EPOCH 32/1000]========
# [TRAIN ACCURACY]: 0.9754
# [TRAIN LOSS]: 7542.4792
# ========[EPOCH 33/1000]========
# [TRAIN ACCURACY]: 0.9772
# [TRAIN LOSS]: 6913.3526
# ========[EPOCH 34/1000]========
# [TRAIN ACCURACY]: 0.9798
# [TRAIN LOSS]: 5830.2889
# ========[EPOCH 35/1000]========
# [TRAIN ACCURACY]: 0.9634
# [TRAIN LOSS]: 10468.6115
# ========[EPOCH 36/1000]========
# [TRAIN ACCURACY]: 0.9805
# [TRAIN LOSS]: 5684.7723
# ========[EPOCH 37/1000]========
# [TRAIN ACCURACY]: 0.9822
# [TRAIN LOSS]: 5321.7763
# ========[EPOCH 38/1000]========
# [TRAIN ACCURACY]: 0.9789
# [TRAIN LOSS]: 6261.2626
# ========[EPOCH 39/1000]========
# [TRAIN ACCURACY]: 0.9839
# [TRAIN LOSS]: 4674.5649
# ========[EPOCH 40/1000]========
# [TRAIN ACCURACY]: 0.9818
# [TRAIN LOSS]: 5346.2159
# [VALIDATION ACCURACY]: 0.9704
# ========[EPOCH 41/1000]========
# [TRAIN ACCURACY]: 0.9842
# [TRAIN LOSS]: 4450.5324
# ========[EPOCH 42/1000]========
# [TRAIN ACCURACY]: 0.9860
# [TRAIN LOSS]: 4069.4110
# ========[EPOCH 43/1000]========
# [TRAIN ACCURACY]: 0.9869
# [TRAIN LOSS]: 3696.4944
# ========[EPOCH 44/1000]========
# [TRAIN ACCURACY]: 0.9880
# [TRAIN LOSS]: 3499.4117
# ========[EPOCH 45/1000]========
# [TRAIN ACCURACY]: 0.9879
# [TRAIN LOSS]: 3447.6363
# ========[EPOCH 46/1000]========
# [TRAIN ACCURACY]: 0.9848
# [TRAIN LOSS]: 4378.2136
# ========[EPOCH 47/1000]========
# [TRAIN ACCURACY]: 0.9871
# [TRAIN LOSS]: 3877.2310
# ========[EPOCH 48/1000]========
# [TRAIN ACCURACY]: 0.9892
# [TRAIN LOSS]: 3105.6955
# ========[EPOCH 49/1000]========
# [TRAIN ACCURACY]: 0.9890
# [TRAIN LOSS]: 3145.8167
# ========[EPOCH 50/1000]========
# [TRAIN ACCURACY]: 0.9901
# [TRAIN LOSS]: 2736.3698
# [VALIDATION ACCURACY]: 0.9818
# ========[EPOCH 51/1000]========
# [TRAIN ACCURACY]: 0.9898
# [TRAIN LOSS]: 3038.0534
# ========[EPOCH 52/1000]========
# [TRAIN ACCURACY]: 0.9881
# [TRAIN LOSS]: 3579.8999
# ========[EPOCH 53/1000]========
# [TRAIN ACCURACY]: 0.9898
# [TRAIN LOSS]: 3117.4630
# ========[EPOCH 54/1000]========
# [TRAIN ACCURACY]: 0.9877
# [TRAIN LOSS]: 3547.9464
# ========[EPOCH 55/1000]========
# [TRAIN ACCURACY]: 0.9903
# [TRAIN LOSS]: 2848.4148
# ========[EPOCH 56/1000]========
# [TRAIN ACCURACY]: 0.9910
# [TRAIN LOSS]: 2645.0341
# ========[EPOCH 57/1000]========
# [TRAIN ACCURACY]: 0.9909
# [TRAIN LOSS]: 2558.3365
# ========[EPOCH 58/1000]========
# [TRAIN ACCURACY]: 0.9910
# [TRAIN LOSS]: 2596.9129
# ========[EPOCH 59/1000]========
# [TRAIN ACCURACY]: 0.9915
# [TRAIN LOSS]: 2596.2227
# ========[EPOCH 60/1000]========
# [TRAIN ACCURACY]: 0.9884
# [TRAIN LOSS]: 3491.5850
# [VALIDATION ACCURACY]: 0.9792
# ========[EPOCH 61/1000]========
# [TRAIN ACCURACY]: 0.9914
# [TRAIN LOSS]: 2498.8046
# ========[EPOCH 62/1000]========
# [TRAIN ACCURACY]: 0.9918
# [TRAIN LOSS]: 2412.8269
# ========[EPOCH 63/1000]========
# [TRAIN ACCURACY]: 0.9916
# [TRAIN LOSS]: 2630.6977
# ========[EPOCH 64/1000]========
# [TRAIN ACCURACY]: 0.9918
# [TRAIN LOSS]: 2328.0822
# ========[EPOCH 65/1000]========
# [TRAIN ACCURACY]: 0.9929
# [TRAIN LOSS]: 2121.6839
# ========[EPOCH 66/1000]========
# [TRAIN ACCURACY]: 0.9933
# [TRAIN LOSS]: 1947.6242
# ========[EPOCH 67/1000]========
# [TRAIN ACCURACY]: 0.9931
# [TRAIN LOSS]: 2051.0659
# ========[EPOCH 68/1000]========
# [TRAIN ACCURACY]: 0.9920
# [TRAIN LOSS]: 2266.0921
# ========[EPOCH 69/1000]========
# [TRAIN ACCURACY]: 0.9935
# [TRAIN LOSS]: 1941.5648
# ========[EPOCH 70/1000]========
# [TRAIN ACCURACY]: 0.9933
# [TRAIN LOSS]: 1914.0553
# [VALIDATION ACCURACY]: 0.9829
# ========[EPOCH 71/1000]========
# [TRAIN ACCURACY]: 0.9933
# [TRAIN LOSS]: 1930.7325
# ========[EPOCH 72/1000]========
# [TRAIN ACCURACY]: 0.9908
# [TRAIN LOSS]: 2704.5635
# ========[EPOCH 73/1000]========
# [TRAIN ACCURACY]: 0.9925
# [TRAIN LOSS]: 2194.2966
# ========[EPOCH 74/1000]========
# [TRAIN ACCURACY]: 0.9924
# [TRAIN LOSS]: 2279.4601
# ========[EPOCH 75/1000]========
# [TRAIN ACCURACY]: 0.9927
# [TRAIN LOSS]: 2204.1386
# ========[EPOCH 76/1000]========
# [TRAIN ACCURACY]: 0.9905
# [TRAIN LOSS]: 3074.8253
# ========[EPOCH 77/1000]========
# [TRAIN ACCURACY]: 0.9903
# [TRAIN LOSS]: 3088.8360
# ========[EPOCH 78/1000]========
# [TRAIN ACCURACY]: 0.9923
# [TRAIN LOSS]: 2412.3122
# ========[EPOCH 79/1000]========
# [TRAIN ACCURACY]: 0.9939
# [TRAIN LOSS]: 1749.0251
# ========[EPOCH 80/1000]========
# [TRAIN ACCURACY]: 0.9932
# [TRAIN LOSS]: 2169.5480
# [VALIDATION ACCURACY]: 0.9799
# ========[EPOCH 81/1000]========
# [TRAIN ACCURACY]: 0.9936
# [TRAIN LOSS]: 1969.1124
# ========[EPOCH 82/1000]========
# [TRAIN ACCURACY]: 0.9944
# [TRAIN LOSS]: 1615.1214
# ========[EPOCH 83/1000]========
# [TRAIN ACCURACY]: 0.9951
# [TRAIN LOSS]: 1463.0901
# ========[EPOCH 84/1000]========
# [TRAIN ACCURACY]: 0.9952
# [TRAIN LOSS]: 1512.8382
# ========[EPOCH 85/1000]========
# [TRAIN ACCURACY]: 0.9952
# [TRAIN LOSS]: 1445.3956
# ========[EPOCH 86/1000]========
# [TRAIN ACCURACY]: 0.9836
# [TRAIN LOSS]: 4978.4214
# ========[EPOCH 87/1000]========
# [TRAIN ACCURACY]: 0.9926
# [TRAIN LOSS]: 2254.7801
# ========[EPOCH 88/1000]========
# [TRAIN ACCURACY]: 0.9930
# [TRAIN LOSS]: 2172.8190
# ========[EPOCH 89/1000]========
# [TRAIN ACCURACY]: 0.9893
# [TRAIN LOSS]: 3178.4327
# ========[EPOCH 90/1000]========
# [TRAIN ACCURACY]: 0.9928
# [TRAIN LOSS]: 2118.4782
# [VALIDATION ACCURACY]: 0.9822
# ========[EPOCH 91/1000]========
# [TRAIN ACCURACY]: 0.9940
# [TRAIN LOSS]: 1684.4471
# ========[EPOCH 92/1000]========
# [TRAIN ACCURACY]: 0.9949
# [TRAIN LOSS]: 1558.0930
# ========[EPOCH 93/1000]========
# [TRAIN ACCURACY]: 0.9954
# [TRAIN LOSS]: 1360.0820
# ========[EPOCH 94/1000]========
# [TRAIN ACCURACY]: 0.9833
# [TRAIN LOSS]: 4613.8287
# ========[EPOCH 95/1000]========
# [TRAIN ACCURACY]: 0.9948
# [TRAIN LOSS]: 1543.2717
# ========[EPOCH 96/1000]========
# [TRAIN ACCURACY]: 0.9954
# [TRAIN LOSS]: 1400.0233
# ========[EPOCH 97/1000]========
# [TRAIN ACCURACY]: 0.9914
# [TRAIN LOSS]: 2606.5003
# ========[EPOCH 98/1000]========
# [TRAIN ACCURACY]: 0.9899
# [TRAIN LOSS]: 2877.0619
# ========[EPOCH 99/1000]========
# [TRAIN ACCURACY]: 0.9933
# [TRAIN LOSS]: 1995.7148
# ========[EPOCH 100/1000]========
# [TRAIN ACCURACY]: 0.9924
# [TRAIN LOSS]: 2322.4502
# [VALIDATION ACCURACY]: 0.9803
# ========[EPOCH 101/1000]========
# [TRAIN ACCURACY]: 0.9935
# [TRAIN LOSS]: 2105.4227
# ========[EPOCH 102/1000]========
# [TRAIN ACCURACY]: 0.9950
# [TRAIN LOSS]: 1564.8818
# ========[EPOCH 103/1000]========
# [TRAIN ACCURACY]: 0.9956
# [TRAIN LOSS]: 1448.1252
# ========[EPOCH 104/1000]========
# [TRAIN ACCURACY]: 0.9951
# [TRAIN LOSS]: 1621.5534
# ========[EPOCH 105/1000]========
# [TRAIN ACCURACY]: 0.9945
# [TRAIN LOSS]: 1635.3511
# ========[EPOCH 106/1000]========
# [TRAIN ACCURACY]: 0.9960
# [TRAIN LOSS]: 1315.6184
# ========[EPOCH 107/1000]========
# [TRAIN ACCURACY]: 0.9962
# [TRAIN LOSS]: 1272.8568
# ========[EPOCH 108/1000]========
# [TRAIN ACCURACY]: 0.9963
# [TRAIN LOSS]: 1127.1763
# ========[EPOCH 109/1000]========
# [TRAIN ACCURACY]: 0.9963
# [TRAIN LOSS]: 1192.0999
# ========[EPOCH 110/1000]========
# [TRAIN ACCURACY]: 0.9934
# [TRAIN LOSS]: 2102.1027
# [VALIDATION ACCURACY]: 0.9803
# ========[EPOCH 111/1000]========
# [TRAIN ACCURACY]: 0.9954
# [TRAIN LOSS]: 1479.7899
# ========[EPOCH 112/1000]========
# [TRAIN ACCURACY]: 0.9952
# [TRAIN LOSS]: 1550.3961
# ========[EPOCH 113/1000]========
# [TRAIN ACCURACY]: 0.9944
# [TRAIN LOSS]: 1797.6927
# ========[EPOCH 114/1000]========
# [TRAIN ACCURACY]: 0.9944
# [TRAIN LOSS]: 1677.8987
# ========[EPOCH 115/1000]========
# [TRAIN ACCURACY]: 0.9966
# [TRAIN LOSS]: 1181.1789
# ========[EPOCH 116/1000]========
# [TRAIN ACCURACY]: 0.9965
# [TRAIN LOSS]: 1109.1274
# ========[EPOCH 117/1000]========
# [TRAIN ACCURACY]: 0.9962
# [TRAIN LOSS]: 1101.0688
# ========[EPOCH 118/1000]========
# [TRAIN ACCURACY]: 0.9966
# [TRAIN LOSS]: 1155.5206
# ========[EPOCH 119/1000]========
# [TRAIN ACCURACY]: 0.9967
# [TRAIN LOSS]: 945.5935
# ========[EPOCH 120/1000]========
# [TRAIN ACCURACY]: 0.9967
# [TRAIN LOSS]: 1107.4619
# [VALIDATION ACCURACY]: 0.9822
# ========[EPOCH 121/1000]========
# [TRAIN ACCURACY]: 0.9964
# [TRAIN LOSS]: 1205.8660
# ========[EPOCH 122/1000]========
# [TRAIN ACCURACY]: 0.9860
# [TRAIN LOSS]: 4055.9668
# ========[EPOCH 123/1000]========
# [TRAIN ACCURACY]: 0.9863
# [TRAIN LOSS]: 4020.8490
# ========[EPOCH 124/1000]========
# [TRAIN ACCURACY]: 0.9903
# [TRAIN LOSS]: 2846.3858
# ========[EPOCH 125/1000]========
# [TRAIN ACCURACY]: 0.9830
# [TRAIN LOSS]: 5142.5687
# ========[EPOCH 126/1000]========
# [TRAIN ACCURACY]: 0.9873
# [TRAIN LOSS]: 3735.0194
# ========[EPOCH 127/1000]========
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0710154be4e3> in <module>
#      15
#      16         optimizer.zero_grad()
# ---> 17         loss.backward()
#      18         optimizer.step()
#      19
#
# ~\Anaconda3\envs\snowflaketf2.0\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~\Anaconda3\envs\snowflaketf2.0\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
        # Train the generator
        for _ in range(g_iters):
            optimizer_g.zero_grad()

            z = Variable(torch.cuda.FloatTensor(np.random.randn(images.shape[0], 64), device=device))

            generated_images = generator(z)
            gen_logits = discriminator(generated_images)
            g_loss = adversarial_loss(gen_logits, real)

            g_loss.backward()
            optimizer_g.step()
